# %% [markdown]
# # Exercise: Teach an LLM to Spell with Group Relative Policy Optimization (GRPO)

# %% [markdown]
# Large language models (LLMs) are notoriously bad at spelling. This is partly because tokenizers break words into smaller pieces, so the model learns about sub-word units rather than whole words and their spellings.
#
# In this exercise, you'll use Group Relative Policy Optimization (GRPO) and a technique called Parameter-Efficient Fine-Tuning (PEFT) with Low-Rank Adaptation (LoRA) to teach a small LLM how to spell words. This is a classic example of teaching a model a new skill that isn't well-represented in its pre-training data.
#
# ## What you'll do in this notebook
#
# 1.  **Setup**: Import libraries and configure the environment.
# 2.  **Load the tokenizer and base model**: Use a small, instruction-tuned model as our starting point.
# 3.  **Create the dataset**: Generate a simple dataset of words and their correct spellings.
# 4.  **Evaluate the base model**: Test the model's spelling ability *before* fine-tuning to establish a baseline.
# 5.  **Configure LoRA and train**: Attach a LoRA adapter to the model and fine-tune it on the spelling dataset.
# 6.  **Evaluate the fine-tuned model**: Test the model again to see if its spelling has improved.

# %% [markdown]
# ## Setup

# %%
# pip install trl

# %%
# Setup imports
# No changes needed in this cell

import os
import torch
from datasets import Dataset

from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
)
from peft import LoraConfig, get_peft_model
from trl import SFTTrainer, SFTConfig

# Use GPU, MPS, or CPU, in that order of preference
if torch.cuda.is_available():
    device = torch.device("cuda")  # NVIDIA GPU
elif torch.backends.mps.is_available():
    device = torch.device("mps")  # Apple Silicon
else:
    device = torch.device("cpu")
torch.set_num_threads(max(1, os.cpu_count() // 2))
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ## Step 1. Load the tokenizer and base model
#
# The model `HuggingFaceTB/SmolLM2-135M-Instruct` is a small, instruction-tuned model that's suitable for this exercise. It has 135 million parameters, making it lightweight and efficient for fine-tuning. It's not the most powerful model, but it's a good choice for demonstrating the concepts of SFT and PEFT with LoRA, especially on a CPU or limited GPU resources.

# %%
# Student task: Load the model and tokenizer, and copy the model to the device.
# TODO: Complete the sections with **********

# See: https://huggingface.co/docs/transformers/en/models
# See: https://huggingface.co/docs/transformers/en/fast_tokenizers

# Model ID for SmolLM2-135M-Instruct
model_id = "HuggingFaceTB/SmolLM2-135M-Instruct"

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(pretrained_model_name_or_path=model_id)

# Load the model
model = AutoModelForCausalLM.from_pretrained(pretrained_model_name_or_path=model_id)

# Copy the model to the device (GPU, MPS, or CPU)
model = model.to(device)

print("Model parameters (total):", sum(p.numel() for p in model.parameters()))
# Out:
# config.json:   0%|          | 0.00/861 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/655 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/269M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/272 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/132 [00:00<?, ?B/s]
# Model parameters (total): 134515008

# %% [markdown]
# ## Step 2. Create the dataset

# %%
# Create a list of words of different lengths
# No changes are needed in this cell.

# fmt: off
ALL_WORDS = [
    "idea", "glow", "rust", "maze", "echo", "wisp", "veto", "lush", "gaze", "knit", "fume", "plow",
    "void", "oath", "grim", "crisp", "lunar", "fable", "quest", "verge", "brawn", "elude", "aisle",
    "ember", "crave", "ivory", "mirth", "knack", "wryly", "onset", "mosaic", "velvet", "sphinx",
    "radius", "summit", "banner", "cipher", "glisten", "mantle", "scarab", "expose", "fathom",
    "tavern", "fusion", "relish", "lantern", "enchant", "torrent", "capture", "orchard", "eclipse",
    "frescos", "triumph", "absolve", "gossipy", "prelude", "whistle", "resolve", "zealous",
    "mirage", "aperture", "sapphire",
]
# fmt: on

# %%
# Student Task: Create a Hugging Face Dataset with the prompt that asks the model to spell the word
# with hyphens between the letters.
# TODO: Complete the sections with **********


def generate_records():
    for word in ALL_WORDS:
        yield {
            # We will use the GRPOTrainer which expects to receieve formatted prompts
            # to pass to the LLM
            # https://huggingface.co/docs/trl/main/en/grpo_trainer
            "prompt": (
                    f"You spell words with hyphens between the letters like this W-O-R-D.\nWord:\n{word}\n\n"
                + "Spelling:\n"
                ),
            # Before using GRPOTrainer, will run a few epochs of supervised-fine tuning (SFT)
            # which can be useful to give an initial nudge to the model. Thus we need to provide
            # the gold standard answer.z
            # See the documentation for more details:
            # https://huggingface.co/docs/trl/en/sft_trainer#expected-dataset-type-and-format
            "completion": "-".join(word).upper() + ".",
            # GRPOTrainer does not expect a completion, but we can add extra columns to our dataset
            # that our reward functions will use to grade the completions provided by the LLM.
            "word": word,
            "spelling": "-".join(word).upper(),
        }


ds = Dataset.from_generator(generate_records)

ds = ds.train_test_split(test_size=0.1, seed=42)

# Show the first item of the train split
ds["train"][0]
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# {'prompt': 'You spell words with hyphens between the letters like this W-O-R-D.\nWord:\ntriumph\n\nSpelling:\n',
#  'completion': 'T-R-I-U-M-P-H.',
#  'word': 'triumph',
#  'spelling': 'T-R-I-U-M-P-H'}

# %% [markdown]
# ## Step 3. Evaluate the base model
#
# Before we fine-tune the model, let's see how it performs on the spelling task. We'll create a helper function to generate a spelling for a given word and compare it to the correct answer.

# %%
# Create a helper function that will help us visualize the performance of the model
# No changes needed in this cell


def check_spelling(
    model, tokenizer, prompt: str, actual_spelling: str, max_new_tokens: int = 20
) -> (str, str):
    inputs = tokenizer(prompt, return_tensors="pt").to(device)
    gen = model.generate(
        **inputs, max_new_tokens=max_new_tokens, use_cache=False
    )  # No parameters = greedy search
    output = tokenizer.decode(gen[0], skip_special_tokens=True)
    # print(f"Output = {output}\n****************\n")

    # Extract the generated spelling from the full output string
    proposed_spelling = output.split("Spelling:\n")[-1].strip().split("\n")[0].strip()
    # print(f"proposed_spelling = {proposed_spelling}")
    # strip any whitepsace from the actual spelling
    actual_spelling = actual_spelling.strip()

    print(
        f"Proposed: {proposed_spelling} | Actual: {actual_spelling} "
        f"| Matches: {'✅' if proposed_spelling == actual_spelling else '❌'}"
    )

    # Remove hyphens for a character-by-character comparison
    proposed_spelling = proposed_spelling.replace("-", "")
    actual_spelling = actual_spelling.replace("-", "")

    # Calculate the proportion of the spelling that was correct
    num_correct = sum(1 for a, b in zip(actual_spelling, proposed_spelling) if a == b)

    return num_correct / len(actual_spelling)  # Return proportion correct

# %%
# Student task: Evaluate the base model's spelling ability
# We expect it to perform poorly, as it hasn't been trained for this task.

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    spelling = example["spelling"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=spelling,
        max_new_tokens=20,
    )
    proportion_correct += result
    print("=======================================================")

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Proposed: trium | Actual: T-R-I-U-M-P-H | Matches: ❌
# =======================================================
# Proposed: sapp | Actual: S-A-P-P-H-I-R-E | Matches: ❌
# =======================================================
# Proposed: expose | Actual: E-X-P-O-S-E | Matches: ❌
# =======================================================
# Proposed: fres | Actual: F-R-E-S-C-O-S | Matches: ❌
# =======================================================
# Proposed: wisp | Actual: W-I-S-P | Matches: ❌
# =======================================================
# Proposed: mi-er-ge | Actual: M-I-R-A-G-E | Matches: ❌
# =======================================================
# Proposed: ivory | Actual: I-V-O-R-Y | Matches: ❌
# =======================================================
# Proposed: onset | Actual: O-N-S-E-T | Matches: ❌
# =======================================================
# Proposed: elude | Actual: E-L-U-D-E | Matches: ❌
# =======================================================
# Proposed: sphinx | Actual: S-P-H-I-N-X | Matches: ❌
# =======================================================
# Proposed: brawn | Actual: B-R-A-W-N | Matches: ❌
# =======================================================
# Proposed: goss | Actual: G-O-S-S-I-P-Y | Matches: ❌
# =======================================================
# Proposed: enchant | Actual: E-N-C-H-A-N-T | Matches: ❌
# =======================================================
# Proposed: tavern | Actual: T-A-V-E-R-N | Matches: ❌
# =======================================================
# Proposed: whistle | Actual: W-H-I-S-T-L-E | Matches: ❌
# =======================================================
# Proposed: W-O-R-D | Actual: C-A-P-T-U-R-E | Matches: ❌
# =======================================================
# Proposed: echo | Actual: E-C-H-O | Matches: ❌
# =======================================================
# Proposed: mirth | Actual: M-I-R-T-H | Matches: ❌
# =======================================================
# Proposed: cris | Actual: C-R-I-S-P | Matches: ❌
# =======================================================
# Proposed: zeal | Actual: Z-E-A-L-O-U-S | Matches: ❌
# =======================================================
# 0.0/20.0 words correct

# %% [markdown]
# As expected, the base model is terrible at spelling. It mostly just repeats the word back. Now, let's fine-tune it.

# %% [markdown]
# ## Step 4. Configure LoRA and train the model

# %% [markdown]
# Let’s attach a LoRA adapter to the base model. We use a LoRA config so only a tiny fraction of parameters are trainable. Read more here: [LoRA](https://huggingface.co/docs/peft/main/en/conceptual_guides/lora).

# %%
# Student task: Configure LoRA for a causal LM and wrap the model with get_peft_model
# Complete the sections with **********

# Print how many params are trainable at first
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(
    f"Trainable params BEFORE: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)"
)

# See: https://huggingface.co/docs/peft/package_reference/lora
lora_config = LoraConfig(
    r=64,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",         # Causal Language Modeling.
)
# # Wrap the base model with get_peft_model
model = get_peft_model(model=model, peft_config=lora_config)

# Print the number of trainable parameters after applying LoRA
trainable = sum(p.numel() for p in model.parameters() if p.requires_grad)
total = sum(p.numel() for p in model.parameters())
print(
    f"Trainable params AFTER: {trainable:,} / {total:,} ({100 * trainable / total:.2f}%)"
)
# Out:
# Trainable params BEFORE: 134,515,008 / 134,515,008 (100.00%)
# Trainable params AFTER: 3,686,400 / 138,201,408 (2.67%)

# %% [markdown]
# Now let’s set the training arguments. We'll use `SFTConfig` from the TRL library, which is a wrapper around the standard `TrainingArguments`. We keep epochs, batch size, and sequence length modest to finish training quickly.

# %%
# Train the model for a few epochs using SFT before GRPO as in certain cases
# they can work together synergystically.
# See: https://arxiv.org/html/2507.08267v1
# No changes needed here

output_dir = "data/model"

training_args = SFTConfig(
    output_dir=output_dir,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=2,
    num_train_epochs=10,
    learning_rate=5 * 1e-4,
    logging_steps=20,
    eval_strategy="steps",
    eval_steps=20,
    save_strategy="no",
    report_to=[],
    fp16=False,
    lr_scheduler_type="cosine",
)

trainer = SFTTrainer(
    model=model,
    train_dataset=ds["train"],
    eval_dataset=ds["test"],
    args=training_args,
)
trainer.train()

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    spelling = example["spelling"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=spelling,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Adding EOS to train dataset:   0%|          | 0/55 [00:00<?, ? examples/s]
# Tokenizing train dataset:   0%|          | 0/55 [00:00<?, ? examples/s]
# Adding EOS to eval dataset:   0%|          | 0/7 [00:00<?, ? examples/s]
# Tokenizing eval dataset:   0%|          | 0/7 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='70' max='70' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [70/70 00:48, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>1.078614</td>
#       <td>0.873210</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.526583</td>
#       <td>0.747638</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>0.427509</td>
#       <td>0.736901</td>
#     </tr>
#   </tbody>
# </table><p>
# Proposed: T-I-R-U-M-P-H-I-L-E. | Actual: T-R-I-U-M-P-H | Matches: ❌
# Proposed: S-A-P-I-C-H. | Actual: S-A-P-P-H-I-R-E | Matches: ❌
# Proposed: E-X-P-S-E-T. | Actual: E-X-P-O-S-E | Matches: ❌
# Proposed: F-S-R-E-C-O-S. | Actual: F-R-E-S-C-O-S | Matches: ❌
# Proposed: W-I-P-S. | Actual: W-I-S-P | Matches: ❌
# Proposed: M-I-R-E-G. | Actual: M-I-R-A-G-E | Matches: ❌
# Proposed: I-V-O-R-Y. | Actual: I-V-O-R-Y | Matches: ❌
# Proposed: O-N-S-H-O-R-D. | Actual: O-N-S-E-T | Matches: ❌
# Proposed: E-L-E-U-D. | Actual: E-L-U-D-E | Matches: ❌
# Proposed: S-P-H-I-N-K-O. | Actual: S-P-H-I-N-X | Matches: ❌
# Proposed: B-R-A-N-Y. | Actual: B-R-A-W-N | Matches: ❌
# Proposed: G-O-S-H-O-P-I-Y. | Actual: G-O-S-S-I-P-Y | Matches: ❌
# Proposed: E-N-C-H-A-N-T. | Actual: E-N-C-H-A-N-T | Matches: ❌
# Proposed: T-A-A-N-R. | Actual: T-A-V-E-R-N | Matches: ❌
# Proposed: W-H-I-S-E. | Actual: W-H-I-S-T-L-E | Matches: ❌
# Proposed: C-U-P-A-R-E. | Actual: C-A-P-T-U-R-E | Matches: ❌
# Proposed: E-C-H-O-R-E. | Actual: E-C-H-O | Matches: ❌
# Proposed: M-I-R-T. | Actual: M-I-R-T-H | Matches: ❌
# Proposed: C-R-I-S-P. | Actual: C-R-I-S-P | Matches: ❌
# Proposed: Z-E-A-L-O-U-S. | Actual: Z-E-A-L-O-U-S | Matches: ❌
# 13.489285714285714/20.0 words correct

# %% [markdown]
# The number of words has slightly increased. Let's try training using GRPO now.
#
# First let's create some reward functions.

# %%
# Student Task: Create a helper function proportion_correct that takes a word and
# a proposed spelling from the LLM and returns a score where every matched character
# adds +1 and every  mismatched character subtracts 1 from the reward--including the
# hyphens.

import re


def proportion_correct(word, proposed_spelling):
    correct_spelling = "-".join(word).upper()

    score = 0.0

    # Pad to the same length to handle extra characters
    max_len = max(len(correct_spelling), len(proposed_spelling))
    proposed_spelling_padded = proposed_spelling.ljust(max_len, " ")
    correct_spelling_padded = correct_spelling.ljust(max_len, " ")

    for a, b in zip(correct_spelling_padded, proposed_spelling_padded):
      if a==b:
        score += 1
      else:
        score -= 1


    return score / (len(correct_spelling))  # Normalize by length of spelling, including dashes


assert proportion_correct("hello", "H-E-L-L-O") == 9 / 9
assert proportion_correct("hello", "H-E-L-") == 3 / 9
assert proportion_correct("hello", "H-E-L-L-O!") == 8 / 9

# %%
# Create a `reward_spelling` function that receives a batch of completions and the associated word values
# No changes needed here

import numpy as np


def reward_spelling(completions, word, **kwargs):
    """Reward function that rewards completions with more unique letters."""

    completion_strings = [completion.split("\n")[0].strip() for completion in completions]
    words = [w for w in word]

    rewards = [proportion_correct(w, c) for w, c in zip(words, completion_strings)]

    # When training, GRPO will pass multiple completions and words to this function.
    # We print just the first one to observe what is happening under the hood.
    print("=====")
    print(
        "Completion example first line:",
        words[0],
        "->",
        completion_strings[0].strip().split("\n")[0].strip(),
    )
    print(f"Spelling mean and std: {np.mean(rewards):.3f} +/- {np.std(rewards):.3f}")
    return rewards


assert reward_spelling(
    completions=["H-E-L-L-O", "H-E-L-", "H-E-L-L-O!"],
    word=["hello", "hello", "hello",],
) == [1, 3 / 9, 8 / 9]
# Out:
# =====
# Completion example first line: hello -> H-E-L-L-O
# Spelling mean and std: 0.741 +/- 0.292

# %%
# Student task: Create a reward of 1.0 for completions starting with a string
# formatted like X-Y-Z else return 0.0


def reward_response_in_form_of_letter_dash_letter(completions, word, **kwargs):
    """Reward function that gives a bonus for completions in the form of LETTER-DASH-LETTER."""
    pattern = re.compile(r"^([A-Z]-)+[A-Z]")  # Pattern for LETTER-DASH-LETTER

    words = [w for w in word]

    # Normalize the completions, taking the first line and removing extra whitespace
    completion_strings = [
        completion.split("\n")[0].strip() for completion in completions
    ]

    # Create a list of rewards corresponding to completions
    # Each completion that matches the pattern should receive 1.0,
    # else 0.0
    # rewards = [
    #     **********
    # ]

    # <<< START COMPLETION SECTION
    rewards = [
        1.0 if pattern.match(c) else 0.0 for w, c in zip(words, completion_strings)
    ]
    # >>> END COMPLETION SECTION

    print(
        f"Letter-dash-letter rewards mean and std: {np.mean(rewards):.3f} +/- {np.std(rewards):.3f}"
    )
    return rewards


assert reward_response_in_form_of_letter_dash_letter(
    completions=[
        "H-E-L-L-O",
        "hello",
        "Hi!",
    ],
    word=[
        "hello",
        "hello",
        "hello",
    ],
) == [1, 0, 0]
# Out:
# Letter-dash-letter rewards mean and std: 0.333 +/- 0.471

# %%
# Student task: Set the GRPOConfig and initialize the trainer
# See: https://huggingface.co/docs/trl/main/en/grpo_trainer
# TODO: Complete the sections with **********

from trl import GRPOConfig, GRPOTrainer

training_args = GRPOConfig(
    output_dir="data/spelling-grpo",
    max_completion_length=30,
    logging_steps=5,
    learning_rate=5e-5,
    num_train_epochs=10,  # We'll train just for a few epochs
    per_device_train_batch_size=8,  # The batch size for training
    num_generations=4,  # Determines the number of completions to compute for each single prompt
    lr_scheduler_type="cosine",
    beta=0.0,
)
trainer = GRPOTrainer(
    model=model,
    reward_funcs=[
        reward_spelling,
        reward_response_in_form_of_letter_dash_letter,
    ],
    args=training_args,
    train_dataset=ds["train"],
)
trainer.train()
# Out:
# =====
# Completion example first line: mirth -> M-I-H-R-T.
# Spelling mean and std: -0.337 +/- 1.977
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
#     <div>
#
#       <progress value='270' max='270' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [270/270 06:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>5</td>
#       <td>0.029111</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>-0.017324</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>-0.010805</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>-0.030450</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.003889</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.054637</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.059665</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.002341</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.013053</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>0.031512</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>-0.001664</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>-0.085733</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.051369</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>-0.031361</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>-0.004072</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>0.026975</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.031473</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>-0.036514</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>-0.020210</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>-0.039890</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.009645</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.019454</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.002487</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.038812</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>-0.001327</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>0.003216</td>
#     </tr>
#     <tr>
#       <td>135</td>
#       <td>-0.004649</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>0.001679</td>
#     </tr>
#     <tr>
#       <td>145</td>
#       <td>0.009373</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>-0.013351</td>
#     </tr>
#     <tr>
#       <td>155</td>
#       <td>0.016894</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>0.047519</td>
#     </tr>
#     <tr>
#       <td>165</td>
#       <td>0.033511</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>0.056226</td>
#     </tr>
#     <tr>
#       <td>175</td>
#       <td>-0.040039</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>-0.026207</td>
#     </tr>
#     <tr>
#       <td>185</td>
#       <td>-0.017758</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>-0.003043</td>
#     </tr>
#     <tr>
#       <td>195</td>
#       <td>0.006789</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.021755</td>
#     </tr>
#     <tr>
#       <td>205</td>
#       <td>0.008685</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>-0.021000</td>
#     </tr>
#     <tr>
#       <td>215</td>
#       <td>-0.010160</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>0.002377</td>
#     </tr>
#     <tr>
#       <td>225</td>
#       <td>0.012773</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>0.054612</td>
#     </tr>
#     <tr>
#       <td>235</td>
#       <td>-0.019300</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>0.004684</td>
#     </tr>
#     <tr>
#       <td>245</td>
#       <td>-0.010673</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>-0.002087</td>
#     </tr>
#     <tr>
#       <td>255</td>
#       <td>0.008488</td>
#     </tr>
#     <tr>
#       <td>260</td>
#       <td>0.008979</td>
#     </tr>
#     <tr>
#       <td>265</td>
#       <td>0.014327</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>-0.004283</td>
#     </tr>
#   </tbody>
# </table><p>
# =====
# Completion example first line: mantle -> M-A-T-L-R.
# Spelling mean and std: 0.216 +/- 0.358
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: summit -> S-U-M-T-I-N.
# Spelling mean and std: 0.148 +/- 0.393
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-C-E-R.
# Spelling mean and std: 0.253 +/- 0.385
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-Y-L-Y.
# Spelling mean and std: 0.321 +/- 0.364
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-I-S-E-L.
# Spelling mean and std: 0.128 +/- 0.470
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-Q-A-N-R.
# Spelling mean and std: 0.185 +/- 0.092
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-A-R-Y-N.
# Spelling mean and std: 0.153 +/- 0.175
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-P-A-R-I-C-H.
# Spelling mean and std: 0.172 +/- 0.384
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-O-M-H-S.
# Spelling mean and std: -0.123 +/- 0.453
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-O-R.
# Spelling mean and std: -0.005 +/- 0.164
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-T-H.
# Spelling mean and std: 0.260 +/- 0.342
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-S-I-P.
# Spelling mean and std: 0.389 +/- 0.242
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-I-L-E-N-O.
# Spelling mean and std: 0.235 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-S-I-T.
# Spelling mean and std: 0.377 +/- 0.258
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: glow -> G-L-W-O-L-E.
# Spelling mean and std: 0.130 +/- 0.387
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-K-I-T.
# Spelling mean and std: 0.021 +/- 0.447
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-U-R-E-G.
# Spelling mean and std: 0.087 +/- 0.352
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: mirage -> M-I-R-E-A-R.
# Spelling mean and std: 0.352 +/- 0.338
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-A-T.
# Spelling mean and std: 0.077 +/- 0.197
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-O-R-H-E.
# Spelling mean and std: 0.321 +/- 0.483
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-E-C-O-S-S-H-E.
# Spelling mean and std: 0.125 +/- 0.231
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-E-R-U-N-T.
# Spelling mean and std: -0.029 +/- 0.299
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-I-L-S.
# Spelling mean and std: 0.206 +/- 0.152
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-H-M.
# Spelling mean and std: 0.122 +/- 0.300
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-I-F-H.
# Spelling mean and std: -0.174 +/- 0.524
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: elude -> E-L-E-U-D-A-L.
# Spelling mean and std: -0.079 +/- 0.528
# Letter-dash-letter rewards mean and std: 0.750 +/- 0.433
# =====
# Completion example first line: fusion -> F-U-S-E-R.
# Spelling mean and std: 0.159 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-T-I-C-O.
# Spelling mean and std: 0.306 +/- 0.349
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-N-X-A.
# Spelling mean and std: 0.159 +/- 0.366
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-R-L-I-U-E.
# Spelling mean and std: 0.240 +/- 0.174
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-M-H-O.
# Spelling mean and std: -0.245 +/- 0.449
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: brawn -> B-R-A-N-Y.
# Spelling mean and std: 0.423 +/- 0.274
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-A-I-R-C-H.
# Spelling mean and std: 0.142 +/- 0.176
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-I-Y.
# Spelling mean and std: 0.263 +/- 0.370
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-O-L-E-V-T.
# Spelling mean and std: 0.412 +/- 0.379
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-A-B-N-I-R.
# Spelling mean and std: 0.265 +/- 0.288
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-A-R-U-T-E.
# Spelling mean and std: 0.451 +/- 0.371
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-N-T-R-I-L.
# Spelling mean and std: -0.024 +/- 0.448
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: verge -> V-E-R-G-E.
# Spelling mean and std: 0.202 +/- 0.454
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-S-R-C-I-S.
# Spelling mean and std: 0.183 +/- 0.172
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-B.
# Spelling mean and std: 0.333 +/- 0.176
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-O-A-M-E.
# Spelling mean and std: 0.239 +/- 0.374
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-C-A-B.
# Spelling mean and std: 0.325 +/- 0.408
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-A-T-Y.
# Spelling mean and std: 0.195 +/- 0.214
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-I-A-U.
# Spelling mean and std: 0.250 +/- 0.182
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: idea -> D-E-I-A-T.
# Spelling mean and std: -0.001 +/- 0.324
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-I-S-E-L.
# Spelling mean and std: 0.310 +/- 0.469
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-U-R-H-M-P-E.
# Spelling mean and std: 0.125 +/- 0.460
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: radius -> R-U-S-I-A-N.
# Spelling mean and std: -0.096 +/- 0.215
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-E-S-C-L-O-N.
# Spelling mean and std: 0.067 +/- 0.112
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E-N.
# Spelling mean and std: 0.319 +/- 0.429
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-H-O-R-E.
# Spelling mean and std: 0.342 +/- 0.314
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-S.
# Spelling mean and std: 0.107 +/- 0.484
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-N-Y.
# Spelling mean and std: 0.287 +/- 0.174
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E.
# Spelling mean and std: 0.192 +/- 0.421
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-S-S.
# Spelling mean and std: 0.174 +/- 0.162
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-A-P-O-P-I-R-C-H.
# Spelling mean and std: 0.339 +/- 0.352
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-N-A-T-P-R-I-N.
# Spelling mean and std: 0.173 +/- 0.187
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-O-P-S.
# Spelling mean and std: -0.038 +/- 0.077
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-T-R-I-Y.
# Spelling mean and std: 0.362 +/- 0.271
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-I-N-L-O.
# Spelling mean and std: -0.081 +/- 0.325
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.451 +/- 0.441
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-S-O-W-P-I-Y.
# Spelling mean and std: 0.327 +/- 0.244
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-P-L.
# Spelling mean and std: -0.487 +/- 1.813
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-T-R.
# Spelling mean and std: 0.091 +/- 0.169
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-I-S-T.
# Spelling mean and std: 0.316 +/- 0.248
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-I-R-U-M-P-H.
# Spelling mean and std: 0.269 +/- 0.280
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-L-S.
# Spelling mean and std: 0.406 +/- 0.231
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-A-N-N-R-O.
# Spelling mean and std: 0.292 +/- 0.318
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-U-B-E.
# Spelling mean and std: 0.079 +/- 0.146
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: radius -> R-I-S-R-A.
# Spelling mean and std: 0.273 +/- 0.223
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-R-E-L-O.
# Spelling mean and std: 0.366 +/- 0.317
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-V.
# Spelling mean and std: 0.408 +/- 0.423
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-T-H.
# Spelling mean and std: 0.444 +/- 0.318
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-D-A.
# Spelling mean and std: 0.106 +/- 0.154
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E-E.
# Spelling mean and std: 0.649 +/- 0.176
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-UST.
# Spelling mean and std: 0.113 +/- 0.258
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.542 +/- 0.280
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-R-G-E-R.
# Spelling mean and std: 0.538 +/- 0.225
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-H-A-M-T.
# Spelling mean and std: 0.039 +/- 0.162
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-O-T-E.
# Spelling mean and std: 0.331 +/- 0.327
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-R-I-S-T.
# Spelling mean and std: 0.508 +/- 0.362
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-L-E-V-T.
# Spelling mean and std: 0.337 +/- 0.525
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: glow -> G-L-O-W.
# Spelling mean and std: 0.256 +/- 0.303
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-C-U-E-R.
# Spelling mean and std: 0.135 +/- 0.162
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-O-R-D.
# Spelling mean and std: 0.158 +/- 0.300
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-S-I-E-L.
# Spelling mean and std: 0.171 +/- 0.232
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-S.
# Spelling mean and std: 0.059 +/- 0.638
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: rust -> R-A-T-O-R.
# Spelling mean and std: 0.125 +/- 0.374
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.548 +/- 0.288
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-S-R-A-L.
# Spelling mean and std: 0.216 +/- 0.340
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lunar -> L-U-R-N.
# Spelling mean and std: 0.361 +/- 0.155
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-E-S-I-A-N.
# Spelling mean and std: 0.438 +/- 0.326
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-C-R-I-S-L.
# Spelling mean and std: -0.114 +/- 0.227
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-U-H-R-T.
# Spelling mean and std: 0.032 +/- 0.119
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-H-R-M.
# Spelling mean and std: 0.357 +/- 0.277
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-N.
# Spelling mean and std: 0.136 +/- 0.232
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-I-P-S-E.
# Spelling mean and std: 0.147 +/- 0.207
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.286 +/- 0.398
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E-R.
# Spelling mean and std: 0.516 +/- 0.281
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-E-L-R-O-N.
# Spelling mean and std: 0.110 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-V-E.
# Spelling mean and std: 0.240 +/- 0.160
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-I-T-L-E.
# Spelling mean and std: 0.030 +/- 0.441
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-E-A-R-H-O.
# Spelling mean and std: 0.261 +/- 0.409
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I-R-E.
# Spelling mean and std: -0.218 +/- 1.335
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-R-S-E-C-O-S.
# Spelling mean and std: 0.240 +/- 0.273
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-U-R-E.
# Spelling mean and std: 0.473 +/- 0.317
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-S-O-G-P-I-Y.
# Spelling mean and std: 0.128 +/- 0.145
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-S.
# Spelling mean and std: 0.283 +/- 0.310
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: idea -> I-D-O-A-R-K-E.
# Spelling mean and std: 0.143 +/- 0.350
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-I-S.
# Spelling mean and std: 0.341 +/- 0.252
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.456 +/- 0.255
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-S-R-E-C-O-S.
# Spelling mean and std: 0.438 +/- 0.390
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fusion -> F-U-L-L-E-S.
# Spelling mean and std: 0.266 +/- 0.283
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-O-L-V-T.
# Spelling mean and std: 0.374 +/- 0.179
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: glow -> G-L-O-W.
# Spelling mean and std: 0.339 +/- 0.631
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-H.
# Spelling mean and std: -0.049 +/- 0.313
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.681 +/- 0.239
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-H-O-M-S.
# Spelling mean and std: 0.129 +/- 0.190
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-E-C-U-V-E.
# Spelling mean and std: 0.144 +/- 0.226
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-A-B-N-A.
# Spelling mean and std: -0.008 +/- 0.145
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-M-U-P-H.
# Spelling mean and std: 0.327 +/- 0.638
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-K-A-B.
# Spelling mean and std: 0.456 +/- 0.216
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-X-M.
# Spelling mean and std: -0.008 +/- 0.143
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-N-B.
# Spelling mean and std: 0.422 +/- 0.399
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-H-A-T.
# Spelling mean and std: 0.150 +/- 0.468
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-I-N-K-H-R.
# Spelling mean and std: 0.393 +/- 0.398
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-U-T-S.
# Spelling mean and std: 0.130 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-R-P-E-R-T-U-R.
# Spelling mean and std: 0.260 +/- 0.211
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-W-N.
# Spelling mean and std: 0.307 +/- 0.411
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-A-D.
# Spelling mean and std: 0.278 +/- 0.347
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-C-R-D.
# Spelling mean and std: 0.218 +/- 0.227
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: enchant -> E-N-C-H-A-N.
# Spelling mean and std: 0.087 +/- 0.429
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: radius -> R-A-S-I-T-E.
# Spelling mean and std: 0.217 +/- 0.147
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-M.
# Spelling mean and std: 0.302 +/- 0.395
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-M-U-T-I-M.
# Spelling mean and std: 0.182 +/- 0.198
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: tavern -> T-A-A-B-N.
# Spelling mean and std: 0.198 +/- 0.148
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-R-E-V-E.
# Spelling mean and std: 0.234 +/- 0.277
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y.
# Spelling mean and std: 0.333 +/- 0.395
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.560 +/- 0.170
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> W-I-N-K.
# Spelling mean and std: 0.282 +/- 0.388
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-U-R-T-E.
# Spelling mean and std: 0.286 +/- 0.476
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-E-L-V-E-T.
# Spelling mean and std: 0.307 +/- 0.276
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.527 +/- 0.305
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-E-D.
# Spelling mean and std: 0.263 +/- 0.173
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-B-U-R.
# Spelling mean and std: 0.360 +/- 0.286
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-S-I-P.
# Spelling mean and std: 0.482 +/- 0.291
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: prelude -> P-R-E-L-O-D.
# Spelling mean and std: 0.434 +/- 0.262
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-O-R-A-R-I-T.
# Spelling mean and std: 0.212 +/- 0.431
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: relish -> R-E-L-S-H.
# Spelling mean and std: 0.138 +/- 0.188
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-A-N-N-R-E.
# Spelling mean and std: 0.182 +/- 0.211
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-K-A.
# Spelling mean and std: 0.313 +/- 0.075
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-I-S-T.
# Spelling mean and std: 0.333 +/- 0.159
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-Th-A-T.
# Spelling mean and std: 0.291 +/- 0.434
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-S-L.
# Spelling mean and std: -0.012 +/- 0.245
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> Wh-I-C-S.
# Spelling mean and std: 0.015 +/- 0.377
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: capture -> C-A-P-E-R-U-T.
# Spelling mean and std: 0.077 +/- 0.136
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-A-D.
# Spelling mean and std: -0.365 +/- 1.243
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aisle -> A-I-S-E-L-E.
# Spelling mean and std: 0.254 +/- 0.574
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-R-E-G.
# Spelling mean and std: 0.494 +/- 0.289
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gaze -> G-A-Z-E.
# Spelling mean and std: 0.387 +/- 0.475
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-S-O-H-P-Y-I-P.
# Spelling mean and std: 0.379 +/- 0.420
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-L-E-V-T.
# Spelling mean and std: 0.216 +/- 0.311
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-M-H.
# Spelling mean and std: 0.128 +/- 0.115
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-P-R-E-A.
# Spelling mean and std: 0.038 +/- 0.054
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-I-V-E-S. Let me check the next word and see how that flows.
# Spelling mean and std: -0.393 +/- 1.664
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-N-A-B-E-N.
# Spelling mean and std: 0.666 +/- 0.217
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-D-E.
# Spelling mean and std: 0.355 +/- 0.601
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: torrent -> T-O-R-A-C-T.
# Spelling mean and std: 0.308 +/- 0.262
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-T.
# Spelling mean and std: 0.259 +/- 0.156
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-R-I-M-P-H-H.
# Spelling mean and std: 0.501 +/- 0.210
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.405 +/- 0.329
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: expose -> E-X-P-S-T-O.
# Spelling mean and std: 0.255 +/- 0.158
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-T-O-R.
# Spelling mean and std: 0.302 +/- 0.141
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-R-B-I-C-E.
# Spelling mean and std: 0.120 +/- 0.131
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> R-O-H-O-C-D.
# Spelling mean and std: 0.516 +/- 0.370
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-N-L-E.
# Spelling mean and std: 0.341 +/- 0.253
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-I-S-H.
# Spelling mean and std: 0.320 +/- 0.255
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-C-A-B.
# Spelling mean and std: 0.249 +/- 0.155
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-S-E.
# Spelling mean and std: 0.021 +/- 0.208
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-N-Y.
# Spelling mean and std: 0.639 +/- 0.259
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-B-E-U.
# Spelling mean and std: 0.063 +/- 0.558
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: onset -> O-N-S-I-D.
# Spelling mean and std: 0.496 +/- 0.250
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: idea -> D-I-A-E-I.
# Spelling mean and std: 0.214 +/- 0.651
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> I-N-K-T.
# Spelling mean and std: -0.074 +/- 0.312
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-Z-E.
# Spelling mean and std: 0.422 +/- 0.306
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-E-R-G-E.
# Spelling mean and std: 0.448 +/- 0.332
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: sphinx -> S-P-I-H-N-R-E.
# Spelling mean and std: 0.467 +/- 0.333
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-T-O-R.
# Spelling mean and std: 0.056 +/- 0.154
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> TOR-ER-T-R-U.
# Spelling mean and std: 0.276 +/- 0.489
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: ember -> E-M-B-R-I-U-E.
# Spelling mean and std: 0.261 +/- 0.377
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-I-H-M-T.
# Spelling mean and std: -0.107 +/- 0.209
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-A-P-I-S-H.
# Spelling mean and std: 0.245 +/- 0.247
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: verge -> V-R-U-G-E.
# Spelling mean and std: 0.327 +/- 0.190
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-R-A-W-N.
# Spelling mean and std: 0.299 +/- 0.270
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-H-O-R-Y.
# Spelling mean and std: 0.292 +/- 0.455
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: grim -> G-R-M-H.
# Spelling mean and std: 0.318 +/- 0.209
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E-E.
# Spelling mean and std: 0.575 +/- 0.277
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-P-I-N-T.
# Spelling mean and std: 0.397 +/- 0.281
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lunar -> L-U-A-R.
# Spelling mean and std: 0.169 +/- 0.185
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-E-R-U-V-E.
# Spelling mean and std: 0.148 +/- 0.163
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-I-S-H-R-D.
# Spelling mean and std: 0.375 +/- 0.448
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-R-K-B.
# Spelling mean and std: 0.239 +/- 0.227
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-P-T-L-E.
# Spelling mean and std: 0.390 +/- 0.517
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: oath -> O-A-T-H.
# Spelling mean and std: 0.435 +/- 0.302
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-L-A-O-U-S.
# Spelling mean and std: 0.635 +/- 0.192
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-Z-E-S.
# Spelling mean and std: 0.393 +/- 0.402
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-U-R-I-M-P.
# Spelling mean and std: 0.530 +/- 0.267
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-I-S-H.
# Spelling mean and std: 0.307 +/- 0.253
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: frescos -> F-S-R-E-C-O-S.
# Spelling mean and std: 0.260 +/- 0.224
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-A-P-U-R-E.
# Spelling mean and std: -0.078 +/- 0.237
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.485 +/- 0.392
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: wisp -> W-P-E-S.
# Spelling mean and std: 0.429 +/- 0.319
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-P-T-A-R-E.
# Spelling mean and std: 0.203 +/- 0.214
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-T.
# Spelling mean and std: 0.058 +/- 0.339
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-P-A-L-I-C-H.
# Spelling mean and std: 0.468 +/- 0.351
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-O-T-H.
# Spelling mean and std: 0.359 +/- 0.296
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: triumph -> T-I-R-U-M-P-H.
# Spelling mean and std: 0.538 +/- 0.196
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I.
# Spelling mean and std: 0.227 +/- 0.315
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: eclipse -> E-S-C-I-L-O.
# Spelling mean and std: 0.360 +/- 0.394
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-E-T-O.
# Spelling mean and std: 0.284 +/- 0.359
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: enchant -> E-C-N-R-A-T.
# Spelling mean and std: 0.157 +/- 0.115
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: scarab -> S-A-C-R-A-B.
# Spelling mean and std: 0.313 +/- 0.341
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirage -> M-I-R-A-G-E.
# Spelling mean and std: 0.506 +/- 0.245
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: gossipy -> G-O-S-P-O-I-Y.
# Spelling mean and std: 0.384 +/- 0.310
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-I-S-T.
# Spelling mean and std: 0.196 +/- 0.231
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-A-T-R-E.
# Spelling mean and std: 0.169 +/- 0.282
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-Z-E.
# Spelling mean and std: 0.363 +/- 0.259
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-E-S-I-S-C.
# Spelling mean and std: 0.235 +/- 0.234
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ember -> E-M-B-E-U.
# Spelling mean and std: 0.331 +/- 0.178
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: banner -> B-A-N-N-O-R.
# Spelling mean and std: 0.193 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: knit -> N-I-T-K-E.
# Spelling mean and std: 0.008 +/- 0.285
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-O-M-H.
# Spelling mean and std: 0.208 +/- 0.263
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: whistle -> W-H-I-S-C.
# Spelling mean and std: 0.396 +/- 0.269
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: relish -> R-E-L-I-S-H.
# Spelling mean and std: 0.396 +/- 0.257
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-H-R-O.
# Spelling mean and std: 0.146 +/- 0.243
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: crisp -> C-R-S-I-P.
# Spelling mean and std: 0.092 +/- 0.357
# Letter-dash-letter rewards mean and std: 0.875 +/- 0.331
# =====
# Completion example first line: orchard -> O-R-H-C-R-E.
# Spelling mean and std: -0.144 +/- 1.363
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: brawn -> B-A-R-Y-N.
# Spelling mean and std: 0.279 +/- 0.247
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-T-R-L.
# Spelling mean and std: 0.354 +/- 0.344
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-U-T-S.
# Spelling mean and std: 0.360 +/- 0.509
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-C-T.
# Spelling mean and std: 0.284 +/- 0.220
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: cipher -> C-A-F-I-P.
# Spelling mean and std: 0.139 +/- 0.227
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: capture -> C-U-P-E-R.
# Spelling mean and std: 0.163 +/- 0.212
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: lantern -> L-A-N-N-T-E.
# Spelling mean and std: 0.298 +/- 0.174
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: veto -> V-O-E-T.
# Spelling mean and std: 0.325 +/- 0.191
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: echo -> E-C-H-O-R.
# Spelling mean and std: 0.287 +/- 0.281
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: summit -> S-U-M-T-I-N.
# Spelling mean and std: 0.369 +/- 0.198
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fathom -> F-A-M-H-T.
# Spelling mean and std: -0.086 +/- 0.300
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mantle -> M-A-N-T-R-L.
# Spelling mean and std: 0.182 +/- 0.298
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: zealous -> Z-E-A-L-O-U-S.
# Spelling mean and std: 0.720 +/- 0.219
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: elude -> E-L-U-A-D.
# Spelling mean and std: 0.254 +/- 0.358
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: aperture -> A-P-R-E-A-T-U-R-T.
# Spelling mean and std: 0.081 +/- 0.441
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: plow -> P-L-O-W.
# Spelling mean and std: 0.450 +/- 0.401
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: rust -> R-I-T-T-O.
# Spelling mean and std: 0.179 +/- 0.159
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: torrent -> T-A-R-O-R-E-N.
# Spelling mean and std: 0.155 +/- 0.108
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: ivory -> I-V-O-R-Y. Let me check on the second instance.
# Spelling mean and std: 0.319 +/- 0.796
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sapphire -> S-P-A-L-I-C-A.
# Spelling mean and std: 0.405 +/- 0.309
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: orchard -> O-R-H-C-E-D.
# Spelling mean and std: 0.452 +/- 0.341
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: absolve -> A-B-R-I-E.
# Spelling mean and std: 0.158 +/- 0.321
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mosaic -> M-A-S-I-Q-T.
# Spelling mean and std: 0.230 +/- 0.170
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: onset -> O-N-S-H-D.
# Spelling mean and std: 0.235 +/- 0.209
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: fume -> F-U-M-E.
# Spelling mean and std: 0.750 +/- 0.199
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: resolve -> R-I-S-S.
# Spelling mean and std: 0.153 +/- 0.330
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: mirth -> M-I-R-T.
# Spelling mean and std: 0.398 +/- 0.177
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: sphinx -> S-P-H-P-I-N.
# Spelling mean and std: 0.484 +/- 0.298
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: velvet -> V-L-E-V-T.
# Spelling mean and std: 0.254 +/- 0.252
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: maze -> M-A-S-E-A-M.
# Spelling mean and std: 0.482 +/- 0.414
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# =====
# Completion example first line: void -> V-A-T-O.
# Spelling mean and std: 0.151 +/- 0.161
# Letter-dash-letter rewards mean and std: 1.000 +/- 0.000
# TrainOutput(global_step=270, training_loss=0.004340869664318032, metrics={'train_runtime': 390.8979, 'train_samples_per_second': 1.407, 'train_steps_per_second': 0.691, 'total_flos': 0.0, 'train_loss': 0.004340869664318032})

# %% [markdown]
# Now we define the `SFTTrainer` and run the fine-tuning process.

# %% [markdown]
# ## Step 5. Evaluate the fine-tuned model

# %%
# Evaluate the fine-tuned model on the same training examples
# No changes needed in this cell

proportion_correct = 0.0

for example in ds["train"].select(range(20)):
    prompt = example["prompt"]
    completion = example["completion"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=completion,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/20.0 words correct")
# Out:
# Proposed: T-R-I-U-M-P-H. | Actual: T-R-I-U-M-P-H. | Matches: ✅
# Proposed: S-A-P-I-C-R-H. | Actual: S-A-P-P-H-I-R-E. | Matches: ❌
# Proposed: E-X-P-S-E. | Actual: E-X-P-O-S-E. | Matches: ❌
# Proposed: F-R-S-E-C-O-S. | Actual: F-R-E-S-C-O-S. | Matches: ❌
# Proposed: W-I-P-S. | Actual: W-I-S-P. | Matches: ❌
# Proposed: M-I-R-G-E. | Actual: M-I-R-A-G-E. | Matches: ❌
# Proposed: I-V-O-R-Y. | Actual: I-V-O-R-Y. | Matches: ✅
# Proposed: O-N-S-I-T. | Actual: O-N-S-E-T. | Matches: ❌
# Proposed: E-L-U-D-E. | Actual: E-L-U-D-E. | Matches: ✅
# Proposed: S-P-H-I-N-X. | Actual: S-P-H-I-N-X. | Matches: ✅
# Proposed: B-R-A-N-Y. | Actual: B-R-A-W-N. | Matches: ❌
# Proposed: G-O-S-H-O-P-I-Y. | Actual: G-O-S-S-I-P-Y. | Matches: ❌
# Proposed: E-N-C-H-A-N. | Actual: E-N-C-H-A-N-T. | Matches: ❌
# Proposed: T-A-A-N-R. | Actual: T-A-V-E-R-N. | Matches: ❌
# Proposed: W-H-I-S-T. | Actual: W-H-I-S-T-L-E. | Matches: ❌
# Proposed: C-U-P-H-R-E. | Actual: C-A-P-T-U-R-E. | Matches: ❌
# Proposed: E-C-H-O-R-E. | Actual: E-C-H-O. | Matches: ❌
# Proposed: M-I-R-T. | Actual: M-I-R-T-H. | Matches: ❌
# Proposed: C-R-I-S-P. | Actual: C-R-I-S-P. | Matches: ✅
# Proposed: Z-E-A-L-O-U-S. | Actual: Z-E-A-L-O-U-S. | Matches: ✅
# 14.060714285714285/20.0 words correct

# %% [markdown]
# The model now performs better on the training data it has seen. But has it generalized? Let's check its performance on the unseen test set.

# %%
# Evaluate the fine-tuned model on the unseen test set
# No changes needed in this cell

proportion_correct = 0.0
num_examples = len(ds["test"])

for example in ds["test"]:
    prompt = example["prompt"]
    completion = example["completion"]
    result = check_spelling(
        model=model,
        tokenizer=tokenizer,
        prompt=prompt,
        actual_spelling=completion,
        max_new_tokens=20,
    )
    proportion_correct += result

print(f"{proportion_correct}/{num_examples}.0 words correct")
# Out:
# Proposed: W-R-Y-I-L-Y. | Actual: W-R-Y-L-Y. | Matches: ❌
# Proposed: G-I-L-N-E. | Actual: G-L-I-S-T-E-N. | Matches: ❌
# Proposed: C-A-S-E. | Actual: Q-U-E-S-T. | Matches: ❌
# Proposed: C-R-E-A-V. | Actual: C-R-A-V-E. | Matches: ❌
# Proposed: L-U-S-I-O. | Actual: L-U-S-H. | Matches: ❌
# Proposed: F-A-L-I-C-E. | Actual: F-A-B-L-E. | Matches: ❌
# Proposed: K-N-A-R-C-E. | Actual: K-N-A-C-K. | Matches: ❌
# 2.5583333333333336/7.0 words correct

# %% [markdown]
# It looks like it has improved! Perhaps with a larger dataset and more training, it could get even better.

# %% [markdown]
# ## Congratulations for completing the exercise! 🎉
#
# ✅ You did it! You successfully fine-tuned a small language model using PEFT with LoRA to teach it a new skill: spelling! You saw how the base model failed completely at the task, and with a very small amount of data and a short training run, the model started to learn how to spell.

# %% [markdown]
# <br /><br /><br /><br /><br /><br /><br /><br /><br />
