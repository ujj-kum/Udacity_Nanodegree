# %%
import nbformat

nb = nbformat.read("Generating Text/huggingface_demo.ipynb", as_version=4)

if "widgets" in nb["metadata"]:
    del nb["metadata"]["widgets"]

nbformat.write(nb, "Generating Text/huggingface_demo_fixed.ipynb")
